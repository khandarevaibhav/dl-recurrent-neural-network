# %%
import numpy as np

# %%
time = np.arange(0, 1500)

# %%
time.shape
# Out:
# (1500,)

# %%
time
# Out:
# array([   0,    1,    2, ..., 1497, 1498, 1499])

# %%
profit = np.sin( 0.02 *  time )

# %%
profit
# Out:
# array([ 0.        ,  0.01999867,  0.03998933, ..., -0.99550324,
#        -0.99340972, -0.99091885])

# %%
y.shape
# Out:
# (1500,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( profit)

# %%
# np.linspace(0,20, 10)

# %%
# np.pi

# %%
# inp = np.linspace( -np.pi,  np.pi, 20)

# %%
# inp

# %%
# opt = np.sin(inp)

# %%
# opt

# %%
# plt.plot( inp , opt , marker='o')

# %%
profit_with_noise = np.sin( 0.02 *  time ) +  np.random.uniform( low=-1 , high=1 , size=(1500,))

# %%
plt.plot(profit, color='green')
# plt.plot(profit_with_noise, color='blue')
plt.show()

# %%
plt.plot(profit_with_noise, color='blue')
